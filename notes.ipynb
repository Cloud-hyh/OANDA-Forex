# %% [markdown]
# #Introduction To OANDA-System
#
# * * *
#
# ##Environment:
#
# * Python-Anaconda 2.7
# * pandas, json, requests
#
#
#
# ###Config Class
#
# * Contains infomations that we need to connect to OANDA server and make requests.

# %%
from api import*

myConfig = Config()
myConfig.view()
# Out:
# {
#     "config_body": {
#         "account_id": 2804581,
#         "domain": "api-sandbox.oanda.com",
#         "domain_stream": "stream-sandbox.oanda.com",
#         "header": {
#             "Authorization": "Bearer 4c56cbf8105642050bbfdb36aad29c6a-77dfc84d1fc6a2ced8e1b15641d0d69e",
#             "Connection": "keep-alive",
#             "Content-Type": "application/x-www-form-urlencoded",
#             "X-Accept-Datetime-Format": "unix"
#         },
#         "password": "DequejHid&",
#         "ssl": false,
#         "username": "geonaroben",
#         "version": "v1"
#     },
#     "config_head": "my token",
#     "user_token": "4c56cbf8105642050bbfdb36aad29c6a-77dfc84d1fc6a2ced8e1b15641d0d69e"
# }

# %% [markdown]
# * * *
#
# ###Data Containers
#
# * Tick
# * Bar
#
# ###Event Objects
#
# * market event
# * bar event
# * signal event
# * order event
# * fill event
#
#
# ###Event Queue Object
#
# * Should be structured in a dictionary with specific names.

# %%
q1 = EventQueue()
q2 = EventQueue()
q = {'mkt': q1, 'bar': q2}

# %% [markdown]
# ###Api class
#
# * The object that make every requests. Basis of the entire system.
# * Initialized with Config( ) and a dictionary of event queues. ( )

# %%
myapi = PyApi(Config(), q)

# %% [markdown]
# ###Simple Requests
#
# * get instruments
# * get account infomation
# * get positions
# * get orders
# * get price
# * get historical data
#
# the return value of these functions are json-like dictionaries. (see examples)
#
# ####get_instruments( )

# %%
instrumentList = myapi.get_instruments()
print instrumentList
# Out:
# {u'instruments': [{u'pip': u'1.0', u'instrument': u'AU200_AUD', u'maxTradeUnits': 200, u'displayName': u'Australia 200'}, {u'pip': u'0.0001', u'instrument': u'AUD_CAD', u'maxTradeUnits': 10000000, u'displayName': u'AUD/CAD'}, {u'pip': u'0.0001', u'instrument': u'AUD_CHF', u'maxTradeUnits': 10000000, u'displayName': u'AUD/CHF'}, {u'pip': u'0.0001', u'instrument': u'AUD_HKD', u'maxTradeUnits': 10000000, u'displayName': u'AUD/HKD'}, {u'pip': u'0.01', u'instrument': u'AUD_JPY', u'maxTradeUnits': 10000000, u'displayName': u'AUD/JPY'}, {u'pip': u'0.0001', u'instrument': u'AUD_NZD', u'maxTradeUnits': 10000000, u'displayName': u'AUD/NZD'}, {u'pip': u'0.0001', u'instrument': u'AUD_SGD', u'maxTradeUnits': 10000000, u'displayName': u'AUD/SGD'}, {u'pip': u'0.0001', u'instrument': u'AUD_USD', u'maxTradeUnits': 10000000, u'displayName': u'AUD/USD'}, {u'pip': u'0.01', u'instrument': u'BCO_USD', u'maxTradeUnits': 10000, u'displayName': u'Brent Crude Oil'}, {u'pip': u'0.0001', u'instrument': u'CAD_CHF', u'maxTradeUnits': 10000000, u'displayName': u'CAD/CHF'}, {u'pip': u'0.0001', u'instrument': u'CAD_HKD', u'maxTradeUnits': 10000000, u'displayName': u'CAD/HKD'}, {u'pip': u'0.01', u'instrument': u'CAD_JPY', u'maxTradeUnits': 10000000, u'displayName': u'CAD/JPY'}, {u'pip': u'0.0001', u'instrument': u'CAD_SGD', u'maxTradeUnits': 10000000, u'displayName': u'CAD/SGD'}, {u'pip': u'1.0', u'instrument': u'CH20_CHF', u'maxTradeUnits': 100, u'displayName': u'Swiss 20'}, {u'pip': u'0.0001', u'instrument': u'CHF_HKD', u'maxTradeUnits': 10000000, u'displayName': u'CHF/HKD'}, {u'pip': u'0.01', u'instrument': u'CHF_JPY', u'maxTradeUnits': 10000000, u'displayName': u'CHF/JPY'}, {u'pip': u'0.0001', u'instrument': u'CHF_ZAR', u'maxTradeUnits': 10000000, u'displayName': u'CHF/ZAR'}, {u'pip': u'0.01', u'instrument': u'CORN_USD', u'maxTradeUnits': 150000, u'displayName': u'Corn'}, {u'pip': u'0.01', u'instrument': u'DE10YB_EUR', u'maxTradeUnits': 6000, u'displayName': u'Germany 10Y Bund'}, {u'pip': u'1.0', u'instrument': u'DE30_EUR', u'maxTradeUnits': 100, u'displayName': u'Germany 30'}, {u'pip': u'1.0', u'instrument': u'EU50_EUR', u'maxTradeUnits': 300, u'displayName': u'Europe 50'}, {u'pip': u'0.0001', u'instrument': u'EUR_AUD', u'maxTradeUnits': 10000000, u'displayName': u'EUR/AUD'}, {u'pip': u'0.0001', u'instrument': u'EUR_CAD', u'maxTradeUnits': 10000000, u'displayName': u'EUR/CAD'}, {u'pip': u'0.0001', u'instrument': u'EUR_CHF', u'maxTradeUnits': 10000000, u'displayName': u'EUR/CHF'}, {u'pip': u'0.0001', u'instrument': u'EUR_CZK', u'maxTradeUnits': 10000000, u'displayName': u'EUR/CZK'}, {u'pip': u'0.0001', u'instrument': u'EUR_DKK', u'maxTradeUnits': 10000000, u'displayName': u'EUR/DKK'}, {u'pip': u'0.0001', u'instrument': u'EUR_GBP', u'maxTradeUnits': 10000000, u'displayName': u'EUR/GBP'}, {u'pip': u'0.0001', u'instrument': u'EUR_HKD', u'maxTradeUnits': 10000000, u'displayName': u'EUR/HKD'}, {u'pip': u'0.01', u'instrument': u'EUR_HUF', u'maxTradeUnits': 10000000, u'displayName': u'EUR/HUF'}, {u'pip': u'0.01', u'instrument': u'EUR_JPY', u'maxTradeUnits': 10000000, u'displayName': u'EUR/JPY'}, {u'pip': u'0.0001', u'instrument': u'EUR_NOK', u'maxTradeUnits': 10000000, u'displayName': u'EUR/NOK'}, {u'pip': u'0.0001', u'instrument': u'EUR_NZD', u'maxTradeUnits': 10000000, u'displayName': u'EUR/NZD'}, {u'pip': u'0.0001', u'instrument': u'EUR_PLN', u'maxTradeUnits': 10000000, u'displayName': u'EUR/PLN'}, {u'pip': u'0.0001', u'instrument': u'EUR_SEK', u'maxTradeUnits': 10000000, u'displayName': u'EUR/SEK'}, {u'pip': u'0.0001', u'instrument': u'EUR_SGD', u'maxTradeUnits': 10000000, u'displayName': u'EUR/SGD'}, {u'pip': u'0.0001', u'instrument': u'EUR_TRY', u'maxTradeUnits': 10000000, u'displayName': u'EUR/TRY'}, {u'pip': u'0.0001', u'instrument': u'EUR_USD', u'maxTradeUnits': 10000000, u'displayName': u'EUR/USD'}, {u'pip': u'0.0001', u'instrument': u'EUR_ZAR', u'maxTradeUnits': 10000000, u'displayName': u'EUR/ZAR'}, {u'pip': u'1.0', u'instrument': u'FR40_EUR', u'maxTr ...

# %% [markdown]
# ###Beautify JSON output

# %%
import json
print json.dumps(instrumentList, sort_keys=True, indent=4)
# Out:
# {
#     "instruments": [
#         {
#             "displayName": "Australia 200",
#             "instrument": "AU200_AUD",
#             "maxTradeUnits": 200,
#             "pip": "1.0"
#         },
#         {
#             "displayName": "AUD/CAD",
#             "instrument": "AUD_CAD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "AUD/CHF",
#             "instrument": "AUD_CHF",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "AUD/HKD",
#             "instrument": "AUD_HKD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "AUD/JPY",
#             "instrument": "AUD_JPY",
#             "maxTradeUnits": 10000000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "AUD/NZD",
#             "instrument": "AUD_NZD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "AUD/SGD",
#             "instrument": "AUD_SGD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "AUD/USD",
#             "instrument": "AUD_USD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Brent Crude Oil",
#             "instrument": "BCO_USD",
#             "maxTradeUnits": 10000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "CAD/CHF",
#             "instrument": "CAD_CHF",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "CAD/HKD",
#             "instrument": "CAD_HKD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "CAD/JPY",
#             "instrument": "CAD_JPY",
#             "maxTradeUnits": 10000000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "CAD/SGD",
#             "instrument": "CAD_SGD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Swiss 20",
#             "instrument": "CH20_CHF",
#             "maxTradeUnits": 100,
#             "pip": "1.0"
#         },
#         {
#             "displayName": "CHF/HKD",
#             "instrument": "CHF_HKD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "CHF/JPY",
#             "instrument": "CHF_JPY",
#             "maxTradeUnits": 10000000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "CHF/ZAR",
#             "instrument": "CHF_ZAR",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Corn",
#             "instrument": "CORN_USD",
#             "maxTradeUnits": 150000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Germany 10Y Bund",
#             "instrument": "DE10YB_EUR",
#             "maxTradeUnits": 6000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Germany 30",
#             "instrument": "DE30_EUR",
#             "maxTradeUnits": 100,
#             "pip": "1.0"
#         },
#         {
#             "displayName": "Europe 50",
#             "instrument": "EU50_EUR",
#             "maxTradeUnits": 300,
#             "pip": "1.0"
#         },
#         {
#             "displayName": "EUR/AUD",
#             "instrument": "EUR_AUD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "EUR/CAD",
#             "instrument": "EUR_CAD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "EUR/CHF",
#             "instrument": "EUR_CHF",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "EUR/CZK",
#             "instrument": "EUR_CZK",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "EUR/DKK",
#             "instrument": "EUR_DKK",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "EUR/GBP",
#             "instrument": "EUR_GBP",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "EUR/HKD",
#             "instrument": "EUR_HKD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "EUR/HUF",
#             "instrument": "EUR_HUF",
#             "maxTradeUnits": 10000000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "EUR/JPY",
#             "instrument": "EUR_JPY",
#             "maxTradeUnits": 10000000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "EUR/NOK",
#             "instrument": "EUR_NOK",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "EUR/NZD",
#             "instrument": "EUR_NZD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "EUR/PLN",
#             "instrument": "EUR_PLN",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "EUR/SEK",
#             "instrument": "EUR_SEK",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "EUR/SGD",
#             "instrument": "EUR_SGD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "EUR/TRY",
#             "instrument": "EUR_TRY",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "EUR/USD",
#             "instrument": "EUR_USD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "EUR/ZAR",
#             "instrument": "EUR_ZAR",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "France 40",
#             "instrument": "FR40_EUR",
#             "maxTradeUnits": 200,
#             "pip": "1.0"
#         },
#         {
#             "displayName": "GBP/AUD",
#             "instrument": "GBP_AUD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "GBP/CAD",
#             "instrument": "GBP_CAD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "GBP/CHF",
#             "instrument": "GBP_CHF",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "GBP/HKD",
#             "instrument": "GBP_HKD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "GBP/JPY",
#             "instrument": "GBP_JPY",
#             "maxTradeUnits": 10000000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "GBP/NZD",
#             "instrument": "GBP_NZD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "GBP/PLN",
#             "instrument": "GBP_PLN",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "GBP/SGD",
#             "instrument": "GBP_SGD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "GBP/USD",
#             "instrument": "GBP_USD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "GBP/ZAR",
#             "instrument": "GBP_ZAR",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Hong Kong 33",
#             "instrument": "HK33_HKD",
#             "maxTradeUnits": 400,
#             "pip": "1.0"
#         },
#         {
#             "displayName": "HKD/JPY",
#             "instrument": "HKD_JPY",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Japan 225",
#             "instrument": "JP225_USD",
#             "maxTradeUnits": 100,
#             "pip": "1.0"
#         },
#         {
#             "displayName": "US Nas 100",
#             "instrument": "NAS100_USD",
#             "maxTradeUnits": 400,
#             "pip": "1.0"
#         },
#         {
#             "displayName": "Natural Gas",
#             "instrument": "NATGAS_USD",
#             "maxTradeUnits": 250000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Netherlands 25",
#             "instrument": "NL25_EUR",
#             "maxTradeUnits": 2000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "NZD/CAD",
#             "instrument": "NZD_CAD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "NZD/CHF",
#             "instrument": "NZD_CHF",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "NZD/HKD",
#             "instrument": "NZD_HKD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "NZD/JPY",
#             "instrument": "NZD_JPY",
#             "maxTradeUnits": 10000000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "NZD/SGD",
#             "instrument": "NZD_SGD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "NZD/USD",
#             "instrument": "NZD_USD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "SGD/CHF",
#             "instrument": "SGD_CHF",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "SGD/HKD",
#             "instrument": "SGD_HKD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "SGD/JPY",
#             "instrument": "SGD_JPY",
#             "maxTradeUnits": 10000000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Soybeans",
#             "instrument": "SOYBN_USD",
#             "maxTradeUnits": 60000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "US SPX 500",
#             "instrument": "SPX500_USD",
#             "maxTradeUnits": 800,
#             "pip": "1.0"
#         },
#         {
#             "displayName": "Sugar",
#             "instrument": "SUGAR_USD",
#             "maxTradeUnits": 4000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "TRY/JPY",
#             "instrument": "TRY_JPY",
#             "maxTradeUnits": 10000000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "UK 100",
#             "instrument": "UK100_GBP",
#             "maxTradeUnits": 100,
#             "pip": "1.0"
#         },
#         {
#             "displayName": "UK 10Y Gilt",
#             "instrument": "UK10YB_GBP",
#             "maxTradeUnits": 6000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "US Russ 2000",
#             "instrument": "US2000_USD",
#             "maxTradeUnits": 1000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "US Wall St 30",
#             "instrument": "US30_USD",
#             "maxTradeUnits": 100,
#             "pip": "1.0"
#         },
#         {
#             "displayName": "US 2Y T-Note",
#             "instrument": "USB02Y_USD",
#             "maxTradeUnits": 6000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "US 5Y T-Note",
#             "instrument": "USB05Y_USD",
#             "maxTradeUnits": 6000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "US 10Y T-Note",
#             "instrument": "USB10Y_USD",
#             "maxTradeUnits": 6000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "US T-Bond",
#             "instrument": "USB30Y_USD",
#             "maxTradeUnits": 6000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "USD/CAD",
#             "instrument": "USD_CAD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/CHF",
#             "instrument": "USD_CHF",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/CNH",
#             "instrument": "USD_CNH",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/CNY",
#             "instrument": "USD_CNY",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/CZK",
#             "instrument": "USD_CZK",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/DKK",
#             "instrument": "USD_DKK",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/HKD",
#             "instrument": "USD_HKD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/HUF",
#             "instrument": "USD_HUF",
#             "maxTradeUnits": 10000000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "USD/INR",
#             "instrument": "USD_INR",
#             "maxTradeUnits": 10000000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "USD/JPY",
#             "instrument": "USD_JPY",
#             "maxTradeUnits": 10000000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "USD/MXN",
#             "instrument": "USD_MXN",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/NOK",
#             "instrument": "USD_NOK",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/PLN",
#             "instrument": "USD_PLN",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/SAR",
#             "instrument": "USD_SAR",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/SEK",
#             "instrument": "USD_SEK",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/SGD",
#             "instrument": "USD_SGD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/THB",
#             "instrument": "USD_THB",
#             "maxTradeUnits": 10000000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "USD/TRY",
#             "instrument": "USD_TRY",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/TWD",
#             "instrument": "USD_TWD",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "USD/ZAR",
#             "instrument": "USD_ZAR",
#             "maxTradeUnits": 10000000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Wheat",
#             "instrument": "WHEAT_USD",
#             "maxTradeUnits": 150000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "West Texas Oil",
#             "instrument": "WTICO_USD",
#             "maxTradeUnits": 10000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Silver/AUD",
#             "instrument": "XAG_AUD",
#             "maxTradeUnits": 100000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Silver/CAD",
#             "instrument": "XAG_CAD",
#             "maxTradeUnits": 100000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Silver/CHF",
#             "instrument": "XAG_CHF",
#             "maxTradeUnits": 100000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Silver/EUR",
#             "instrument": "XAG_EUR",
#             "maxTradeUnits": 100000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Silver/GBP",
#             "instrument": "XAG_GBP",
#             "maxTradeUnits": 100000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Silver/HKD",
#             "instrument": "XAG_HKD",
#             "maxTradeUnits": 100000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Silver/JPY",
#             "instrument": "XAG_JPY",
#             "maxTradeUnits": 100000,
#             "pip": "1.0"
#         },
#         {
#             "displayName": "Silver/NZD",
#             "instrument": "XAG_NZD",
#             "maxTradeUnits": 100000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Silver/SGD",
#             "instrument": "XAG_SGD",
#             "maxTradeUnits": 100000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Silver",
#             "instrument": "XAG_USD",
#             "maxTradeUnits": 100000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Gold/AUD",
#             "instrument": "XAU_AUD",
#             "maxTradeUnits": 5000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Gold/CAD",
#             "instrument": "XAU_CAD",
#             "maxTradeUnits": 5000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Gold/CHF",
#             "instrument": "XAU_CHF",
#             "maxTradeUnits": 5000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Gold/EUR",
#             "instrument": "XAU_EUR",
#             "maxTradeUnits": 5000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Gold/GBP",
#             "instrument": "XAU_GBP",
#             "maxTradeUnits": 5000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Gold/HKD",
#             "instrument": "XAU_HKD",
#             "maxTradeUnits": 5000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Gold/JPY",
#             "instrument": "XAU_JPY",
#             "maxTradeUnits": 5000,
#             "pip": "10"
#         },
#         {
#             "displayName": "Gold/NZD",
#             "instrument": "XAU_NZD",
#             "maxTradeUnits": 5000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Gold/SGD",
#             "instrument": "XAU_SGD",
#             "maxTradeUnits": 5000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Gold",
#             "instrument": "XAU_USD",
#             "maxTradeUnits": 5000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Gold/Silver",
#             "instrument": "XAU_XAG",
#             "maxTradeUnits": 5000,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Copper",
#             "instrument": "XCU_USD",
#             "maxTradeUnits": 250000,
#             "pip": "0.0001"
#         },
#         {
#             "displayName": "Palladium",
#             "instrument": "XPD_USD",
#             "maxTradeUnits": 500,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "Platinum",
#             "instrument": "XPT_USD",
#             "maxTradeUnits": 500,
#             "pip": "0.01"
#         },
#         {
#             "displayName": "ZAR/JPY",
#             "instrument": "ZAR_JPY",
#             "maxTradeUnits": 10000000,
#             "pip": "0.01"
#         }
#     ]
# }

# %% [markdown]
# ####get_prices(instrument)
# * instrument: string

# %%
print json.dumps(myapi.get_prices("EUR_USD"), sort_keys=True, indent=4)
# Out:
# {
#     "prices": [
#         {
#             "ask": 1.24068,
#             "bid": 1.24054,
#             "instrument": "EUR_USD",
#             "time": "1442024548072937"
#         }
#     ]
# }

# %% [markdown]
# ####get_account_info(account_id=-1)
# * account_id: integer/string, the account id. Default = -1, use that in config.

# %%
print json.dumps(myapi.get_account_info(), sort_keys=True, indent=4)
# Out:
# {
#     "accountCurrency": "USD",
#     "accountId": 2804581,
#     "accountName": "Primary",
#     "balance": 100010.825,
#     "marginAvail": 99997.1247,
#     "marginRate": 0.05,
#     "marginUsed": 13.7024,
#     "openOrders": 1,
#     "openTrades": 4,
#     "realizedPl": -0.0125,
#     "unrealizedPl": 0.0021
# }

# %% [markdown]
# ####get_positions( )
# * TODO:

# %%
print json.dumps(myapi.get_positions(), sort_keys=True, indent=4)
# Out:
# {
#     "positions": [
#         {
#             "avgPrice": 1.24082,
#             "instrument": "EUR_USD",
#             "side": "sell",
#             "units": 100
#         },
#         {
#             "avgPrice": 1.14339,
#             "instrument": "USD_CAD",
#             "side": "buy",
#             "units": 150
#         }
#     ]
# }

# %% [markdown]
# ####get_orders( )
# * TODO:

# %%
print json.dumps(myapi.get_orders(), sort_keys=True, indent=4)
# Out:
# {
#     "orders": [
#         {
#             "expiry": "1442094172000000",
#             "id": 175583929,
#             "instrument": "USD_CAD",
#             "lowerBound": 0,
#             "price": 0.994,
#             "side": "buy",
#             "stopLoss": 0,
#             "takeProfit": 0,
#             "time": "1442022173000000",
#             "trailingStop": 0,
#             "type": "limit",
#             "units": 50,
#             "upperBound": 0
#         }
#     ]
# }

# %% [markdown]
# ####get_trades( )
# * TODO:

# %%
print json.dumps(myapi.get_trades(), sort_keys=True, indent=4)
# Out:
# {
#     "trades": [
#         {
#             "id": 175583938,
#             "instrument": "USD_CAD",
#             "price": 1.14335,
#             "side": "buy",
#             "stopLoss": 0,
#             "takeProfit": 0,
#             "time": "1442023302000000",
#             "trailingAmount": 0,
#             "trailingStop": 0,
#             "units": 100
#         },
#         {
#             "id": 175583937,
#             "instrument": "EUR_USD",
#             "price": 1.24082,
#             "side": "sell",
#             "stopLoss": 0,
#             "takeProfit": 0,
#             "time": "1442023190000000",
#             "trailingAmount": 0,
#             "trailingStop": 0,
#             "units": 50
#         },
#         {
#             "id": 175583936,
#             "instrument": "EUR_USD",
#             "price": 1.24082,
#             "side": "sell",
#             "stopLoss": 0,
#             "takeProfit": 0,
#             "time": "1442023181000000",
#             "trailingAmount": 0,
#             "trailingStop": 0,
#             "units": 50
#         },
#         {
#             "id": 175583930,
#             "instrument": "USD_CAD",
#             "price": 1.14346,
#             "side": "buy",
#             "stopLoss": 0,
#             "takeProfit": 0,
#             "time": "1442022173000000",
#             "trailingAmount": 0,
#             "trailingStop": 0,
#             "units": 50
#         }
#     ]
# }

# %% [markdown]
# ####place_order( )
# * params: see docs in .py file

# %%
print json.dumps(myapi.get_positions(), sort_keys=True, indent=4)
myapi.place_order('USD_CAD', 'sell', 150, None, 'market') #fill USD_CAD long position
print '\n--------------AFTER--------------\n'
print json.dumps(myapi.get_positions(), sort_keys=True, indent=4)
# Out:
# {
#     "positions": [
#         {
#             "avgPrice": 1.24082,
#             "instrument": "EUR_USD",
#             "side": "sell",
#             "units": 100
#         },
#         {
#             "avgPrice": 1.14357,
#             "instrument": "USD_CAD",
#             "side": "buy",
#             "units": 150
#         }
#     ]
# }
#
# --------------AFTER--------------
#
# {
#     "positions": [
#         {
#             "avgPrice": 1.24082,
#             "instrument": "EUR_USD",
#             "side": "sell",
#             "units": 100
#         }
#     ]
# }

# %% [markdown]
# ###Streaming
#
# * PyApi.make_stream(instrument)
# * Monitor market impulses.
# * Support strategies.

# %%
from strat import *
class BuyAndHold(BaseStrategy):
    """
    some parameters here.
    """
    instrument = 'USD_CAD'
    BHFlag = True

    def __init__(self, api):
        """
        override constructor.
        """
        self.api = api

    def on_bar(self, event):
        """
        Strategy logics.
        """
        if self.BHFlag: # If BHFlag == True, buy 100 CA dollar
            self.market_buy(100)
            self.BHFlag = 0 # then hold.

        # Print account summary and bar data.
        print '---------------------'
        print json.dumps(self.api.get_account_info(), sort_keys=True, indent=4)
        print '\n---------------------\n'
        event.body.view()
        print '---------------------'

# %%
    q1 = EventQueue()
    q2 = EventQueue()
    q = {'mkt': q1, 'bar': q2} # construct event queues
    
    api = PyApi(Config(), q) # initialize api

    mystrat = BuyAndHold(api) # initialize strategy

    q1.bind('ETYPE_MKT', api.on_market_impulse) # let queues listen to some events
    q2.bind('ETYPE_BAR', mystrat.on_bar)

    q1.open() # start pushing event to strategies and other functions
    q2.open()
    api.make_stream('USD_CAD') # make connection to server.
